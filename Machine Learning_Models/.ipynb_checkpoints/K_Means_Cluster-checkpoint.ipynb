# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import time
import datetime

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
# !pip install joblib

# %%
df = pd.read_csv('data/df_eng.csv', low_memory=False)
df.shape
# Out:
# (138265, 59)

# %%
df_clean = df.dropna()

# %%
df_clean.columns
# Out:
# Index(['price_id', 'daily_price', 'weekly_price', 'cleaning_fee',
#        'security_deposit', 'availability_id', 'availability_30',
#        'availability_60', 'availability_90', 'amenity_id', 'wireless_Internet',
#        'air_conditioning', 'pool', 'self_check_in', 'private_entrance',
#        'breakfast', 'free_parking_on_premises', 'tv', 'gym', 'hot_tub',
#        'indoor_fireplace', 'heating', 'family_kid_friendly', 'washer', 'dryer',
#        'hangers', 'iron', 'shampoo', 'hair_dryer', 'high_chair', 'crib',
#        'carbon_monoxide_detector', 'smoke_detector',
#        'babysitter_recommendations', 'pets_allowed', 'first_aid_kit',
#        'host_id', 'host_since', 'host_is_superhost', 'host_response_time',
#        'property_id', 'number_of_reviews', 'review_scores_rating', 'comments',
#        'neighborhood_id', 'listing_description', 'property_type', 'bedrooms',
#        'bathrooms', 'accommodates', 'beds', 'room_type', 'minimum_nights',
# ...

# %%
df_drop = df.drop(columns=['host_since', 'host_response_time','comments','listing_description','property_type','zipcode','language','price_id','availability_id','amenity_id', 'neighborhood_id'])

# %%
df_drop
# Out:
#         daily_price  weekly_price  cleaning_fee  security_deposit  \
# 0             115.0         735.0          50.0             100.0
# 1             115.0         735.0          50.0             100.0
# 2             115.0         735.0          50.0             100.0
# 3             115.0         735.0          50.0             100.0
# 4             115.0         735.0          50.0             100.0
# ...             ...           ...           ...               ...
# 138260         55.0         400.0          45.0             150.0
# 138261         55.0         400.0          45.0             150.0
# 138262         55.0         400.0          45.0             150.0
# 138263         55.0         400.0          45.0             150.0
# 138264         55.0         400.0          45.0             150.0
#
#         availability_30  availability_60  availability_90  wireless_Internet  \
# 0                     6               11               18                  1
# ...

# %%
# pd.set_option('display.max_columns', None)

# %%
# get dummy is giving me memory error.
data_encoded = pd.get_dummies(df_drop, columns=["room_type","neighbourhood"])

# %%
data_encoded.dtypes
# Out:
# daily_price                     float64
# weekly_price                    float64
# cleaning_fee                    float64
# security_deposit                float64
# availability_30                   int64
#                                  ...
# neighbourhood_Westwood            uint8
# neighbourhood_Whittier            uint8
# neighbourhood_Windsor Square      uint8
# neighbourhood_Winnetka            uint8
# neighbourhood_Woodland Hills      uint8
# Length: 197, dtype: object

# %%
# gather all the PCA components
# rename the PC columns
pc_col_names = ["pc_" + item for item in list(data_encoded.columns[10:])]

# extract the 50 principal components
pc_data = data_encoded.iloc[:, 10:]

# rename the columns
pc_data.columns = pc_col_names

# %%
pc_data.shape
# Out:
# (138265, 187)

# %%
pc_data.head()
# Out:
#    pc_self_check_in  pc_private_entrance  pc_breakfast  \
# 0                 0                    1             0
# 1                 0                    1             0
# 2                 0                    1             0
# 3                 0                    1             0
# 4                 0                    1             0
#
#    pc_free_parking_on_premises  pc_tv  pc_gym  pc_hot_tub  \
# 0                            1      1       0           0
# 1                            1      1       0           0
# 2                            1      1       0           0
# 3                            1      1       0           0
# 4                            1      1       0           0
#
#    pc_indoor_fireplace  pc_heating  pc_family_kid_friendly  ...  \
# 0                    0           1                       0  ...
# 1                    0           1                       0  ...
# 2                    0           1                       0  ...
# ...

# %%
pc_data.dtypes
# Out:
# pc_self_check_in                   int64
# pc_private_entrance                int64
# pc_breakfast                       int64
# pc_free_parking_on_premises        int64
# pc_tv                              int64
#                                    ...
# pc_neighbourhood_Westwood          uint8
# pc_neighbourhood_Whittier          uint8
# pc_neighbourhood_Windsor Square    uint8
# pc_neighbourhood_Winnetka          uint8
# pc_neighbourhood_Woodland Hills    uint8
# Length: 187, dtype: object

# %%
from sklearn.cluster import KMeans
# Fit Kmeans and calculate SSE for each k value
sse = {}
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=1)
    kmeans.fit(pc_data)
    sse[k] = kmeans.inertia_ # sum of squared distances to the closest cluster centers

# %%
# plot SSE for each k
plt.title('The Elbow Method')
plt.xlabel('k')
plt.ylabel('SSE')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()))
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=1)
kmeans.fit(pc_data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=1, tol=0.0001, verbose=0)

# %%
predicted_clusters = kmeans.predict(pc_data)

# %%
predicted_clusters
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %%
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ 2.09544046e-01,  2.02938993e-01,  4.24720309e-02,
#          7.26632703e-01,  8.60167430e-01,  6.45656793e-02,
#          1.26084842e-01,  1.52325849e-01,  9.46314738e-01,
#          5.93097975e-01,  7.07739177e-01,  7.12654566e-01,
#          7.98315455e-01,  7.85054146e-01,  9.16566396e-01,
#          7.97521825e-01,  1.61798213e-02,  1.32357083e-02,
#          7.61834054e-01,  9.38096823e-01,  1.19812601e-02,
#          2.19400425e-01,  6.33291518e-01,  1.74501487e+07,
#          5.97680551e-01,  5.07009638e+06,  8.36775300e+01,
#          9.56925578e+01,  1.21084970e+00,  1.24123806e+00,
#          3.63969176e+00,  1.96060009e+00,  2.39353831e+00,
#          7.75666803e+02,  3.40473419e+01, -1.18351115e+02,
#          8.22533985e-01,  1.77466015e-01,  4.75205812e-16,
#          1.02659942e-02, -2.69315820e-16, -8.77119558e-17,
#          1.46693633e-02,  7.60349197e-03,  8.19231458e-04,
#         -1.50227053e-15, -6.30051566e-15, -9.93129190e-17,
# ...

# %%
cluster_labels = kmeans.labels_
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %%
# neighborhood in LA is spread out.
kmeans.score(pc_data)
# Out:
# -4.308237925188447e+18

# %%
# We can use cluster number 3 based on Elbow graph where we see a sharp decrease or reuse the kmeans.labels_ as number of clusters.

# %%
# get the labels
cluster_labels = kmeans.labels_

# assign these clusters back into the dataframe
pc_data_k3 = pc_data.assign(cluster=cluster_labels)

# display the shape
pc_data_k3.shape
# Out:
# (138265, 188)

# %%
pc_data_k3.cluster.value_counts()
# Out:
# 2    80209
# 0    39061
# 1    18995
# Name: cluster, dtype: int64

# %%
# Combine cluster data and original dataset for visualizations

# %%
other_col_names = list(data_encoded.columns[:44])
other_col_names
# Out:
# ['daily_price',
#  'weekly_price',
#  'cleaning_fee',
#  'security_deposit',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'wireless_Internet',
#  'air_conditioning',
#  'pool',
#  'self_check_in',
#  'private_entrance',
#  'breakfast',
#  'free_parking_on_premises',
#  'tv',
#  'gym',
#  'hot_tub',
#  'indoor_fireplace',
#  'heating',
#  'family_kid_friendly',
#  'washer',
#  'dryer',
#  'hangers',
#  'iron',
#  'shampoo',
#  'hair_dryer',
#  'high_chair',
#  'crib',
#  'carbon_monoxide_detector',
#  'smoke_detector',
#  'babysitter_recommendations',
#  'pets_allowed',
#  'first_aid_kit',
#  'host_id',
#  'host_is_superhost',
#  'property_id',
#  'number_of_reviews',
#  'review_scores_rating',
#  'bedrooms',
#  'bathrooms',
#  'accommodates',
#  'beds',
#  'minimum_nights',
#  'maximum_nights']

# %%
k_means_visual = data_encoded[other_col_names]
k_means_visual.shape
# Out:
# (138265, 44)

# %%
k_means_visual = k_means_visual.assign(cluster=cluster_labels)
k_means_visual.head()
# Out:
#    daily_price  weekly_price  cleaning_fee  security_deposit  availability_30  \
# 0        115.0         735.0          50.0             100.0                6
# 1        115.0         735.0          50.0             100.0                6
# 2        115.0         735.0          50.0             100.0                6
# 3        115.0         735.0          50.0             100.0                6
# 4        115.0         735.0          50.0             100.0                6
#
#    availability_60  availability_90  wireless_Internet  air_conditioning  \
# 0               11               18                  1                 1
# 1               11               18                  1                 1
# 2               11               18                  1                 1
# 3               11               18                  1                 1
# 4               11               18                  1                 1
#
# ...

# %%
k_means_visual.shape
# Out:
# (138265, 45)

# %%
k_means_visual.to_csv('k_means_visual.csv', index=False)

# %%
# !pip install folium

# %%
import numpy as np
import os
import geopandas as gpd
import folium
# %matplotlib inline

# %%
# get only the latitude and longitude of each listing
airbnb_coord = data_encoded[['latitude', 'longitude']]

# concatenate the coordinates with k_means results
k_means_map = pd.concat([k_means_visual, airbnb_coord], axis=1)

# %%
map_df = gpd.read_file('dataset/neighborhood_2.geojson')
map_df.head()
# Out:
#    neighborhood_id    neighbourhood         city state zipcode  \
# 0                1            Acton        Acton    CA   93510
# 1                2            Acton     Palmdale    CA   93550
# 2                3            Acton        Acton    CA   93510
# 3                4            Acton        Acton    CA   93510
# 4                5  Adams-Normandie  Los Angeles    CA   90007
#
#                                               access  \
# 0
# 1                                        Whole house
# 2  Private Bath. Access to kitchen and refrigerat...
# 3  We live on 5 acres and Our Bunkhouse is a sepa...
# 4
#
#                                           transit                     geometry
# 0                                                  POINT (-118.22709 34.53035)
# 1         The train station is only one mile away  POINT (-118.12538 34.48543)
# 2  Just 4 miles from Metro commuter Train station  POINT (-118.21241 34.51013)
# ...

# %%
# construct a geodataframe
k_means_map_geo = gpd.GeoDataFrame(k_means_map, geometry=gpd.points_from_xy(k_means_map.longitude,
                                                                            k_means_map.latitude))

# %%
k_means_map_geo.head()
# Out:
#    daily_price  weekly_price  cleaning_fee  security_deposit  availability_30  \
# 0        115.0         735.0          50.0             100.0                6
# 1        115.0         735.0          50.0             100.0                6
# 2        115.0         735.0          50.0             100.0                6
# 3        115.0         735.0          50.0             100.0                6
# 4        115.0         735.0          50.0             100.0                6
#
#    availability_60  availability_90  wireless_Internet  air_conditioning  \
# 0               11               18                  1                 1
# 1               11               18                  1                 1
# 2               11               18                  1                 1
# 3               11               18                  1                 1
# 4               11               18                  1                 1
#
# ...

# %%
# get beverly hills neighborhood
Beverly_Hills = map_df[map_df.neighbourhood == 'Beverly Hills'].geometry
ax1=Beverly_Hills.plot()

# %%
# get long beach neighborhood
Long_Beach = map_df[map_df.neighbourhood == 'Long Beach'].geometry
ax2=Long_Beach.plot()

# %%
k_means_map_geo['neighbourhood'] = map_df['neighbourhood']

# %%
k_means_map_geo.shape
# Out:
# (138265, 49)

# %%
# get Beverly Hills airbnb listings co-ordinates and their assigned clusters
BH_listings = k_means_map_geo[(k_means_map_geo.neighbourhood == 'Beverly Hills') &
                (k_means_map_geo.cleaning_fee == 50) & (k_means_map_geo.availability_90 >= 18) &
               (k_means_map_geo.daily_price < 150)]
