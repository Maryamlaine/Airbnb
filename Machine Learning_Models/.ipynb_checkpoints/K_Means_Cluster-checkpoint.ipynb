# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import time
import datetime

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
# !pip install joblib

# %%
df = pd.read_csv('../data/df_eng.csv', low_memory=False)
df.shape
# Out:
# (138262, 59)

# %%
df_clean = df.dropna()

# %%
df_clean.columns
# Out:
# Index(['price_id', 'daily_price', 'weekly_price', 'cleaning_fee',
#        'security_deposit', 'availability_id', 'availability_30',
#        'availability_60', 'availability_90', 'amenity_id', 'wireless_Internet',
#        'air_conditioning', 'pool', 'self_check_in', 'private_entrance',
#        'breakfast', 'free_parking_on_premises', 'tv', 'gym', 'hot_tub',
#        'indoor_fireplace', 'heating', 'family_kid_friendly', 'washer', 'dryer',
#        'hangers', 'iron', 'shampoo', 'hair_dryer', 'high_chair', 'crib',
#        'carbon_monoxide_detector', 'smoke_detector',
#        'babysitter_recommendations', 'pets_allowed', 'first_aid_kit',
#        'host_id', 'host_since', 'host_is_superhost', 'host_response_time',
#        'property_id', 'number_of_reviews', 'review_scores_rating', 'comments',
#        'neighborhood_id', 'listing_description', 'property_type', 'bedrooms',
#        'bathrooms', 'accommodates', 'beds', 'room_type', 'minimum_nights',
#        'maximum_nights', 'latitude', 'longitude', 'neighbourhood', 'zipcode',
#        'language'],
#       dtype='object')

# %%
df_drop = df.drop(columns=['host_since', 'host_response_time','comments','listing_description','property_type','zipcode','language','price_id','availability_id','amenity_id', 'neighborhood_id','host_id'])

# %%
df_drop
# Out:
#         daily_price  weekly_price  cleaning_fee  security_deposit  \
# 0             115.0         735.0          50.0             100.0
# 1             115.0         735.0          50.0             100.0
# 2             115.0         735.0          50.0             100.0
# 3             115.0         735.0          50.0             100.0
# 4             115.0         735.0          50.0             100.0
# ...             ...           ...           ...               ...
# 138257         55.0         400.0          45.0             150.0
# 138258         55.0         400.0          45.0             150.0
# 138259         55.0         400.0          45.0             150.0
# 138260         55.0         400.0          45.0             150.0
# 138261         55.0         400.0          45.0             150.0
#
#         availability_30  availability_60  availability_90  wireless_Internet  \
# 0                     6               11               18                  1
# 1                     6               11               18                  1
# 2                     6               11               18                  1
# 3                     6               11               18                  1
# 4                     6               11               18                  1
# ...                 ...              ...              ...                ...
# 138257               30               60               90                  1
# 138258               30               60               90                  1
# 138259               30               60               90                  1
# 138260               30               60               90                  1
# 138261               30               60               90                  1
#
#         air_conditioning  pool  ...  bedrooms  bathrooms  accommodates  beds  \
# 0                      1     0  ...       2.0        1.0             6   4.0
# 1                      1     0  ...       2.0        1.0             6   4.0
# 2                      1     0  ...       2.0        1.0             6   4.0
# 3                      1     0  ...       2.0        1.0             6   4.0
# 4                      1     0  ...       2.0        1.0             6   4.0
# ...                  ...   ...  ...       ...        ...           ...   ...
# 138257                 1     0  ...       1.0        1.0             1   1.0
# 138258                 1     0  ...       1.0        1.0             1   1.0
# 138259                 1     0  ...       1.0        1.0             1   1.0
# 138260                 1     0  ...       1.0        1.0             1   1.0
# 138261                 1     0  ...       1.0        1.0             1   1.0
#
#               room_type  minimum_nights  maximum_nights   latitude  \
# 0       Entire home/apt               1            1125  34.032294
# 1       Entire home/apt               1            1125  34.032294
# 2       Entire home/apt               1            1125  34.032294
# 3       Entire home/apt               1            1125  34.032294
# 4       Entire home/apt               1            1125  34.032294
# ...                 ...             ...             ...        ...
# 138257     Private room               2            1125  34.161427
# 138258     Private room               2            1125  34.161427
# 138259     Private room               2            1125  34.161427
# 138260     Private room               2            1125  34.161427
# 138261     Private room               2            1125  34.161427
#
#          longitude    neighbourhood
# 0      -118.304134  Adams-Normandie
# 1      -118.304134  Adams-Normandie
# 2      -118.304134  Adams-Normandie
# 3      -118.304134  Adams-Normandie
# 4      -118.304134  Adams-Normandie
# ...            ...              ...
# 138257 -118.615453   Woodland Hills
# 138258 -118.615453   Woodland Hills
# 138259 -118.615453   Woodland Hills
# 138260 -118.615453   Woodland Hills
# 138261 -118.615453   Woodland Hills
#
# [138262 rows x 47 columns]

# %%
df_price_hoods = df_drop.groupby('neighbourhood', as_index=False)['daily_price'].mean()

# %%
df_price_hoods
# Out:
#        neighbourhood  daily_price
# 0    Adams-Normandie    82.044888
# 1       Agoura Hills   112.763819
# 2         Agua Dulce   120.000000
# 3           Alhambra    88.700207
# 4           Altadena    89.869256
# ..               ...          ...
# 143         Westwood   147.482091
# 144         Whittier   137.428000
# 145   Windsor Square    99.034483
# 146         Winnetka   164.618497
# 147   Woodland Hills   124.205251
#
# [148 rows x 2 columns]

# %%
top_10 = df_price_hoods.nlargest(10,"daily_price")

# %%
top_10
# Out:
#                              neighbourhood  daily_price
# 8                                   Avalon   550.000000
# 128  Unincorporated Santa Monica Mountains   430.408367
# 23                         Castaic Canyons   395.000000
# 49                            Green Valley   395.000000
# 13                           Beverly Grove   391.216535
# 76                                  Malibu   386.255222
# 59                    Hollywood Hills West   367.767669
# 31                             Diamond Bar   357.000000
# 77                         Manhattan Beach   326.903172
# 97                           Playa del Rey   313.222826

# %%
top_10.plot(kind='bar', x='neighbourhood', y='daily_price')

# %%
top_10_list = top_10['neighbourhood'].to_list()

# %%
top_10_list
# Out:
# ['Avalon',
#  'Unincorporated Santa Monica Mountains',
#  'Castaic Canyons',
#  'Green Valley',
#  'Beverly Grove',
#  'Malibu',
#  'Hollywood Hills West',
#  'Diamond Bar',
#  'Manhattan Beach',
#  'Playa del Rey']

# %%
new_df = df_drop[df_drop['neighbourhood'].isin(top_10_list)]

# %%
new_df
# Out:
#         daily_price  weekly_price  cleaning_fee  security_deposit  \
# 5689          550.0        2800.0         175.0            1000.0
# 5690          550.0        2800.0         175.0            1000.0
# 5691          550.0        2800.0         175.0            1000.0
# 5692          550.0        2800.0         175.0            1000.0
# 5693          550.0        2800.0         175.0            1000.0
# ...             ...           ...           ...               ...
# 112616       1120.0        6000.0         350.0            2500.0
# 112617       1120.0        6000.0         350.0            2500.0
# 112618       1120.0        6000.0         350.0            2500.0
# 112619       1120.0        6000.0         350.0            2500.0
# 112620       1120.0        6000.0         350.0            2500.0
#
#         availability_30  availability_60  availability_90  wireless_Internet  \
# 5689                 21               35               43                  1
# 5690                 21               35               43                  1
# 5691                 21               35               43                  1
# 5692                 21               35               43                  1
# 5693                 21               35               43                  1
# ...                 ...              ...              ...                ...
# 112616                0                3               15                  1
# 112617                0                3               15                  1
# 112618                0                3               15                  1
# 112619                0                3               15                  1
# 112620                0                3               15                  1
#
#         air_conditioning  pool  ...  bedrooms  bathrooms  accommodates  beds  \
# 5689                   0     1  ...       2.0        2.0             6   4.0
# 5690                   0     1  ...       2.0        2.0             6   4.0
# 5691                   0     1  ...       2.0        2.0             6   4.0
# 5692                   0     1  ...       2.0        2.0             6   4.0
# 5693                   0     1  ...       2.0        2.0             6   4.0
# ...                  ...   ...  ...       ...        ...           ...   ...
# 112616                 1     1  ...       4.0        3.0             8   4.0
# 112617                 1     1  ...       4.0        3.0             8   4.0
# 112618                 1     1  ...       4.0        3.0             8   4.0
# 112619                 1     1  ...       4.0        3.0             8   4.0
# 112620                 1     1  ...       4.0        3.0             8   4.0
#
#               room_type  minimum_nights  maximum_nights   latitude  \
# 5689    Entire home/apt               2            1125  33.352341
# 5690    Entire home/apt               2            1125  33.352341
# 5691    Entire home/apt               2            1125  33.352341
# 5692    Entire home/apt               2            1125  33.352341
# 5693    Entire home/apt               2            1125  33.352341
# ...                 ...             ...             ...        ...
# 112616  Entire home/apt               3            1125  34.079541
# 112617  Entire home/apt               3            1125  34.079541
# 112618  Entire home/apt               3            1125  34.079541
# 112619  Entire home/apt               3            1125  34.079541
# 112620  Entire home/apt               3            1125  34.079541
#
#          longitude                          neighbourhood
# 5689   -118.331245                                 Avalon
# 5690   -118.331245                                 Avalon
# 5691   -118.331245                                 Avalon
# 5692   -118.331245                                 Avalon
# 5693   -118.331245                                 Avalon
# ...            ...                                    ...
# 112616 -118.634503  Unincorporated Santa Monica Mountains
# 112617 -118.634503  Unincorporated Santa Monica Mountains
# 112618 -118.634503  Unincorporated Santa Monica Mountains
# 112619 -118.634503  Unincorporated Santa Monica Mountains
# 112620 -118.634503  Unincorporated Santa Monica Mountains
#
# [7741 rows x 47 columns]

# %%
bd_price=new_df['daily_price']

# %%
bd_price
# Out:
# 5689       550.0
# 5690       550.0
# 5691       550.0
# 5692       550.0
# 5693       550.0
#            ...
# 112616    1120.0
# 112617    1120.0
# 112618    1120.0
# 112619    1120.0
# 112620    1120.0
# Name: daily_price, Length: 7741, dtype: float64

# %%
# get dummy
data_encoded = pd.get_dummies(new_df, columns=["room_type","neighbourhood"])

# %%
data_encoded
# Out:
#         daily_price  weekly_price  cleaning_fee  security_deposit  \
# 5689          550.0        2800.0         175.0            1000.0
# 5690          550.0        2800.0         175.0            1000.0
# 5691          550.0        2800.0         175.0            1000.0
# 5692          550.0        2800.0         175.0            1000.0
# 5693          550.0        2800.0         175.0            1000.0
# ...             ...           ...           ...               ...
# 112616       1120.0        6000.0         350.0            2500.0
# 112617       1120.0        6000.0         350.0            2500.0
# 112618       1120.0        6000.0         350.0            2500.0
# 112619       1120.0        6000.0         350.0            2500.0
# 112620       1120.0        6000.0         350.0            2500.0
#
#         availability_30  availability_60  availability_90  wireless_Internet  \
# 5689                 21               35               43                  1
# 5690                 21               35               43                  1
# 5691                 21               35               43                  1
# 5692                 21               35               43                  1
# 5693                 21               35               43                  1
# ...                 ...              ...              ...                ...
# 112616                0                3               15                  1
# 112617                0                3               15                  1
# 112618                0                3               15                  1
# 112619                0                3               15                  1
# 112620                0                3               15                  1
#
#         air_conditioning  pool  ...  neighbourhood_Avalon  \
# 5689                   0     1  ...                     1
# 5690                   0     1  ...                     1
# 5691                   0     1  ...                     1
# 5692                   0     1  ...                     1
# 5693                   0     1  ...                     1
# ...                  ...   ...  ...                   ...
# 112616                 1     1  ...                     0
# 112617                 1     1  ...                     0
# 112618                 1     1  ...                     0
# 112619                 1     1  ...                     0
# 112620                 1     1  ...                     0
#
#         neighbourhood_Beverly Grove  neighbourhood_Castaic Canyons  \
# 5689                              0                              0
# 5690                              0                              0
# 5691                              0                              0
# 5692                              0                              0
# 5693                              0                              0
# ...                             ...                            ...
# 112616                            0                              0
# 112617                            0                              0
# 112618                            0                              0
# 112619                            0                              0
# 112620                            0                              0
#
#         neighbourhood_Diamond Bar  neighbourhood_Green Valley  \
# 5689                            0                           0
# 5690                            0                           0
# 5691                            0                           0
# 5692                            0                           0
# 5693                            0                           0
# ...                           ...                         ...
# 112616                          0                           0
# 112617                          0                           0
# 112618                          0                           0
# 112619                          0                           0
# 112620                          0                           0
#
#         neighbourhood_Hollywood Hills West  neighbourhood_Malibu  \
# 5689                                     0                     0
# 5690                                     0                     0
# 5691                                     0                     0
# 5692                                     0                     0
# 5693                                     0                     0
# ...                                    ...                   ...
# 112616                                   0                     0
# 112617                                   0                     0
# 112618                                   0                     0
# 112619                                   0                     0
# 112620                                   0                     0
#
#         neighbourhood_Manhattan Beach  neighbourhood_Playa del Rey  \
# 5689                                0                            0
# 5690                                0                            0
# 5691                                0                            0
# 5692                                0                            0
# 5693                                0                            0
# ...                               ...                          ...
# 112616                              0                            0
# 112617                              0                            0
# 112618                              0                            0
# 112619                              0                            0
# 112620                              0                            0
#
#         neighbourhood_Unincorporated Santa Monica Mountains
# 5689                                                    0
# 5690                                                    0
# 5691                                                    0
# 5692                                                    0
# 5693                                                    0
# ...                                                   ...
# 112616                                                  1
# 112617                                                  1
# 112618                                                  1
# 112619                                                  1
# 112620                                                  1
#
# [7741 rows x 57 columns]

# %%
data_encoded.dtypes
# Out:
# daily_price                                            float64
# weekly_price                                           float64
# cleaning_fee                                           float64
# security_deposit                                       float64
# availability_30                                          int64
# availability_60                                          int64
# availability_90                                          int64
# wireless_Internet                                        int64
# air_conditioning                                         int64
# pool                                                     int64
# self_check_in                                            int64
# private_entrance                                         int64
# breakfast                                                int64
# free_parking_on_premises                                 int64
# tv                                                       int64
# gym                                                      int64
# hot_tub                                                  int64
# indoor_fireplace                                         int64
# heating                                                  int64
# family_kid_friendly                                      int64
# washer                                                   int64
# dryer                                                    int64
# hangers                                                  int64
# iron                                                     int64
# shampoo                                                  int64
# hair_dryer                                               int64
# high_chair                                               int64
# crib                                                     int64
# carbon_monoxide_detector                                 int64
# smoke_detector                                           int64
# babysitter_recommendations                               int64
# pets_allowed                                             int64
# first_aid_kit                                            int64
# host_is_superhost                                      float64
# property_id                                              int64
# number_of_reviews                                        int64
# review_scores_rating                                   float64
# bedrooms                                               float64
# bathrooms                                              float64
# accommodates                                             int64
# beds                                                   float64
# minimum_nights                                           int64
# maximum_nights                                           int64
# latitude                                               float64
# longitude                                              float64
# room_type_Entire home/apt                                uint8
# room_type_Private room                                   uint8
# neighbourhood_Avalon                                     uint8
# neighbourhood_Beverly Grove                              uint8
# neighbourhood_Castaic Canyons                            uint8
# neighbourhood_Diamond Bar                                uint8
# neighbourhood_Green Valley                               uint8
# neighbourhood_Hollywood Hills West                       uint8
# neighbourhood_Malibu                                     uint8
# neighbourhood_Manhattan Beach                            uint8
# neighbourhood_Playa del Rey                              uint8
# neighbourhood_Unincorporated Santa Monica Mountains      uint8
# dtype: object

# %%
# gather all the PCA components
# rename the PC columns
pc_col_names = ["pc_" + item for item in list(data_encoded.columns[10:])]

# extract the 50 principal components
pc_data = data_encoded.iloc[:, 10:]

# rename the columns
pc_data.columns = pc_col_names

# %%
pc_data.shape
# Out:
# (7741, 47)

# %%
pc_data.head()
# Out:
#       pc_self_check_in  pc_private_entrance  pc_breakfast  \
# 5689                 0                    1             0
# 5690                 0                    1             0
# 5691                 0                    1             0
# 5692                 0                    1             0
# 5693                 0                    1             0
#
#       pc_free_parking_on_premises  pc_tv  pc_gym  pc_hot_tub  \
# 5689                            0      1       1           0
# 5690                            0      1       1           0
# 5691                            0      1       1           0
# 5692                            0      1       1           0
# 5693                            0      1       1           0
#
#       pc_indoor_fireplace  pc_heating  pc_family_kid_friendly  ...  \
# 5689                    1           1                       1  ...
# 5690                    1           1                       1  ...
# 5691                    1           1                       1  ...
# 5692                    1           1                       1  ...
# 5693                    1           1                       1  ...
#
#       pc_neighbourhood_Avalon  pc_neighbourhood_Beverly Grove  \
# 5689                        1                               0
# 5690                        1                               0
# 5691                        1                               0
# 5692                        1                               0
# 5693                        1                               0
#
#       pc_neighbourhood_Castaic Canyons  pc_neighbourhood_Diamond Bar  \
# 5689                                 0                             0
# 5690                                 0                             0
# 5691                                 0                             0
# 5692                                 0                             0
# 5693                                 0                             0
#
#       pc_neighbourhood_Green Valley  pc_neighbourhood_Hollywood Hills West  \
# 5689                              0                                      0
# 5690                              0                                      0
# 5691                              0                                      0
# 5692                              0                                      0
# 5693                              0                                      0
#
#       pc_neighbourhood_Malibu  pc_neighbourhood_Manhattan Beach  \
# 5689                        0                                 0
# 5690                        0                                 0
# 5691                        0                                 0
# 5692                        0                                 0
# 5693                        0                                 0
#
#       pc_neighbourhood_Playa del Rey  \
# 5689                               0
# 5690                               0
# 5691                               0
# 5692                               0
# 5693                               0
#
#       pc_neighbourhood_Unincorporated Santa Monica Mountains
# 5689                                                  0
# 5690                                                  0
# 5691                                                  0
# 5692                                                  0
# 5693                                                  0
#
# [5 rows x 47 columns]

# %%
pc_data.dtypes
# Out:
# pc_self_check_in                                            int64
# pc_private_entrance                                         int64
# pc_breakfast                                                int64
# pc_free_parking_on_premises                                 int64
# pc_tv                                                       int64
# pc_gym                                                      int64
# pc_hot_tub                                                  int64
# pc_indoor_fireplace                                         int64
# pc_heating                                                  int64
# pc_family_kid_friendly                                      int64
# pc_washer                                                   int64
# pc_dryer                                                    int64
# pc_hangers                                                  int64
# pc_iron                                                     int64
# pc_shampoo                                                  int64
# pc_hair_dryer                                               int64
# pc_high_chair                                               int64
# pc_crib                                                     int64
# pc_carbon_monoxide_detector                                 int64
# pc_smoke_detector                                           int64
# pc_babysitter_recommendations                               int64
# pc_pets_allowed                                             int64
# pc_first_aid_kit                                            int64
# pc_host_is_superhost                                      float64
# pc_property_id                                              int64
# pc_number_of_reviews                                        int64
# pc_review_scores_rating                                   float64
# pc_bedrooms                                               float64
# pc_bathrooms                                              float64
# pc_accommodates                                             int64
# pc_beds                                                   float64
# pc_minimum_nights                                           int64
# pc_maximum_nights                                           int64
# pc_latitude                                               float64
# pc_longitude                                              float64
# pc_room_type_Entire home/apt                                uint8
# pc_room_type_Private room                                   uint8
# pc_neighbourhood_Avalon                                     uint8
# pc_neighbourhood_Beverly Grove                              uint8
# pc_neighbourhood_Castaic Canyons                            uint8
# pc_neighbourhood_Diamond Bar                                uint8
# pc_neighbourhood_Green Valley                               uint8
# pc_neighbourhood_Hollywood Hills West                       uint8
# pc_neighbourhood_Malibu                                     uint8
# pc_neighbourhood_Manhattan Beach                            uint8
# pc_neighbourhood_Playa del Rey                              uint8
# pc_neighbourhood_Unincorporated Santa Monica Mountains      uint8
# dtype: object

# %%
from sklearn.cluster import KMeans
# Fit Kmeans and calculate SSE for each k value
sse = {}
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=1)
    kmeans.fit(pc_data)
    sse[k] = kmeans.inertia_ # sum of squared distances to the closest cluster centers

# %%
# plot SSE for each k
plt.title('The Elbow Method')
plt.xlabel('k')
plt.ylabel('SSE')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()))
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=1)
kmeans.fit(pc_data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=1, tol=0.0001, verbose=0)

# %%
predicted_clusters = kmeans.predict(pc_data)

# %%
predicted_clusters
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ 2.88433382e-01,  2.02928258e-01,  8.96046852e-02,
#          9.65446559e-01,  8.98389458e-01,  2.34260615e-02,
#          1.87115666e-01,  4.14348463e-01,  9.83308931e-01,
#          7.67203514e-01,  9.63689605e-01,  9.63689605e-01,
#          7.20058565e-01,  6.99853587e-01,  6.47437775e-01,
#          6.97803807e-01, -9.15933995e-16,  2.84040996e-02,
#          6.64128843e-01,  7.99121523e-01,  0.00000000e+00,
#          1.79795022e-01,  3.41142020e-01,  4.82869693e-01,
#          1.27173290e+06,  6.45935578e+01,  9.52108346e+01,
#          2.04070278e+00,  1.84421669e+00,  4.89194729e+00,
#          2.63572474e+00,  2.84568082e+00,  4.58922108e+02,
#          3.40626809e+01, -1.18496526e+02,  8.76720351e-01,
#          1.23279649e-01, -4.78783679e-16,  1.36749634e-01,
#          8.58688121e-17,  2.63543192e-03,  1.50227053e-15,
#          3.90043924e-01,  2.54465593e-01,  4.80234261e-02,
#          3.77745242e-02,  1.30307467e-01],
#        [ 3.27362293e-01,  5.30228392e-01,  5.64263323e-02,
#          8.53560233e-01,  9.54769369e-01,  1.66144201e-01,
#          2.43170622e-01,  3.66771160e-01,  9.82086879e-01,
#          7.70712047e-01,  6.94581281e-01,  6.94581281e-01,
#          8.00268697e-01,  6.78459472e-01,  8.30721003e-01,
#          8.24003583e-01,  6.18002687e-02,  6.18002687e-02,
#          6.63233318e-01,  8.17733990e-01,  0.00000000e+00,
#          3.94984326e-01,  6.47111509e-01,  5.46350202e-01,
#          8.33230072e+06,  4.89991043e+01,  9.70873265e+01,
#          2.29153605e+00,  2.01545007e+00,  5.20465741e+00,
#          2.84236453e+00,  2.06538289e+00,  1.02821675e+03,
#          3.40214028e+01, -1.18490222e+02,  8.54903717e-01,
#          1.45096283e-01,  5.28437080e-02,  1.53605016e-01,
#         -4.77048956e-18,  4.47828034e-04,  7.35522754e-16,
#          3.84684281e-01,  1.50470219e-01,  9.44917152e-02,
#          1.79131214e-02,  1.45544111e-01],
#        [ 1.49546106e-01,  3.10081223e-01, -7.77156117e-16,
#          9.33588151e-01,  8.27520306e-01,  5.49450549e-02,
#          1.37601529e-01,  3.73626374e-01,  9.71333015e-01,
#          7.35785953e-01,  8.21309126e-01,  8.21309126e-01,
#          5.65217391e-01,  5.15050167e-01,  8.17486861e-01,
#          6.52173913e-01, -6.76542156e-16,  8.07453416e-02,
#          8.65742953e-01,  9.71333015e-01,  0.00000000e+00,
#          1.53846154e-01,  4.77305303e-01,  2.80936455e-01,
#          4.78270491e+06,  4.94214047e+01,  9.70387004e+01,
#          1.91304348e+00,  1.80578118e+00,  4.25513617e+00,
#          2.51170569e+00,  2.62637363e+00,  9.60705686e+02,
#          3.40954566e+01, -1.18535364e+02,  9.10654563e-01,
#          8.93454372e-02, -4.11129464e-16,  9.84233158e-02,
#          8.60009556e-03,  5.39932682e-17,  8.07453416e-02,
#          2.24080268e-01,  3.62159580e-01,  1.07023411e-01,
#          7.16674630e-03,  1.11801242e-01]])

# %%
cluster_labels = kmeans.labels_
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# neighborhood in LA is spread out.
kmeans.score(pc_data)
# Out:
# -5375355767452216.0

# %%
# We can use cluster number 3 based on Elbow graph where we see a sharp decrease or reuse the kmeans.labels_ as number of clusters.

# %%
# get the labels
cluster_labels = kmeans.labels_

# assign these clusters back into the dataframe
pc_data_k3 = pc_data.assign(cluster=cluster_labels)

# display the shape
pc_data_k3.shape
# Out:
# (7741, 48)

# %%
pc_data_k3.head()
# Out:
#       pc_self_check_in  pc_private_entrance  pc_breakfast  \
# 5689                 0                    1             0
# 5690                 0                    1             0
# 5691                 0                    1             0
# 5692                 0                    1             0
# 5693                 0                    1             0
#
#       pc_free_parking_on_premises  pc_tv  pc_gym  pc_hot_tub  \
# 5689                            0      1       1           0
# 5690                            0      1       1           0
# 5691                            0      1       1           0
# 5692                            0      1       1           0
# 5693                            0      1       1           0
#
#       pc_indoor_fireplace  pc_heating  pc_family_kid_friendly  ...  \
# 5689                    1           1                       1  ...
# 5690                    1           1                       1  ...
# 5691                    1           1                       1  ...
# 5692                    1           1                       1  ...
# 5693                    1           1                       1  ...
#
#       pc_neighbourhood_Beverly Grove  pc_neighbourhood_Castaic Canyons  \
# 5689                               0                                 0
# 5690                               0                                 0
# 5691                               0                                 0
# 5692                               0                                 0
# 5693                               0                                 0
#
#       pc_neighbourhood_Diamond Bar  pc_neighbourhood_Green Valley  \
# 5689                             0                              0
# 5690                             0                              0
# 5691                             0                              0
# 5692                             0                              0
# 5693                             0                              0
#
#       pc_neighbourhood_Hollywood Hills West  pc_neighbourhood_Malibu  \
# 5689                                      0                        0
# 5690                                      0                        0
# 5691                                      0                        0
# 5692                                      0                        0
# 5693                                      0                        0
#
#       pc_neighbourhood_Manhattan Beach  pc_neighbourhood_Playa del Rey  \
# 5689                                 0                               0
# 5690                                 0                               0
# 5691                                 0                               0
# 5692                                 0                               0
# 5693                                 0                               0
#
#       pc_neighbourhood_Unincorporated Santa Monica Mountains  cluster
# 5689                                                  0             1
# 5690                                                  0             1
# 5691                                                  0             1
# 5692                                                  0             1
# 5693                                                  0             1
#
# [5 rows x 48 columns]

# %%
pc_data_k3.cluster.value_counts()
# Out:
# 0    3415
# 1    2233
# 2    2093
# Name: cluster, dtype: int64

# %%
# Combine cluster data and original dataset for visualizations

# %%
other_col_names = list(data_encoded.columns[:])
other_col_names
# Out:
# ['daily_price',
#  'weekly_price',
#  'cleaning_fee',
#  'security_deposit',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'wireless_Internet',
#  'air_conditioning',
#  'pool',
#  'self_check_in',
#  'private_entrance',
#  'breakfast',
#  'free_parking_on_premises',
#  'tv',
#  'gym',
#  'hot_tub',
#  'indoor_fireplace',
#  'heating',
#  'family_kid_friendly',
#  'washer',
#  'dryer',
#  'hangers',
#  'iron',
#  'shampoo',
#  'hair_dryer',
#  'high_chair',
#  'crib',
#  'carbon_monoxide_detector',
#  'smoke_detector',
#  'babysitter_recommendations',
#  'pets_allowed',
#  'first_aid_kit',
#  'host_is_superhost',
#  'property_id',
#  'number_of_reviews',
#  'review_scores_rating',
#  'bedrooms',
#  'bathrooms',
#  'accommodates',
#  'beds',
#  'minimum_nights',
#  'maximum_nights',
#  'latitude',
#  'longitude',
#  'room_type_Entire home/apt',
#  'room_type_Private room',
#  'neighbourhood_Avalon',
#  'neighbourhood_Beverly Grove',
#  'neighbourhood_Castaic Canyons',
#  'neighbourhood_Diamond Bar',
#  'neighbourhood_Green Valley',
#  'neighbourhood_Hollywood Hills West',
#  'neighbourhood_Malibu',
#  'neighbourhood_Manhattan Beach',
#  'neighbourhood_Playa del Rey',
#  'neighbourhood_Unincorporated Santa Monica Mountains']

# %%
k_means_visual = data_encoded[other_col_names]
k_means_visual.shape
# Out:
# (7741, 57)

# %%
k_means_visual = k_means_visual.assign(cluster=cluster_labels)
k_means_visual.head()
# Out:
#       daily_price  weekly_price  cleaning_fee  security_deposit  \
# 5689        550.0        2800.0         175.0            1000.0
# 5690        550.0        2800.0         175.0            1000.0
# 5691        550.0        2800.0         175.0            1000.0
# 5692        550.0        2800.0         175.0            1000.0
# 5693        550.0        2800.0         175.0            1000.0
#
#       availability_30  availability_60  availability_90  wireless_Internet  \
# 5689               21               35               43                  1
# 5690               21               35               43                  1
# 5691               21               35               43                  1
# 5692               21               35               43                  1
# 5693               21               35               43                  1
#
#       air_conditioning  pool  ...  neighbourhood_Beverly Grove  \
# 5689                 0     1  ...                            0
# 5690                 0     1  ...                            0
# 5691                 0     1  ...                            0
# 5692                 0     1  ...                            0
# 5693                 0     1  ...                            0
#
#       neighbourhood_Castaic Canyons  neighbourhood_Diamond Bar  \
# 5689                              0                          0
# 5690                              0                          0
# 5691                              0                          0
# 5692                              0                          0
# 5693                              0                          0
#
#       neighbourhood_Green Valley  neighbourhood_Hollywood Hills West  \
# 5689                           0                                   0
# 5690                           0                                   0
# 5691                           0                                   0
# 5692                           0                                   0
# 5693                           0                                   0
#
#       neighbourhood_Malibu  neighbourhood_Manhattan Beach  \
# 5689                     0                              0
# 5690                     0                              0
# 5691                     0                              0
# 5692                     0                              0
# 5693                     0                              0
#
#       neighbourhood_Playa del Rey  \
# 5689                            0
# 5690                            0
# 5691                            0
# 5692                            0
# 5693                            0
#
#       neighbourhood_Unincorporated Santa Monica Mountains  cluster
# 5689                                                  0          1
# 5690                                                  0          1
# 5691                                                  0          1
# 5692                                                  0          1
# 5693                                                  0          1
#
# [5 rows x 58 columns]

# %%
k_means_visual.shape
# Out:
# (7741, 58)

# %%
k_means_visual.to_csv('../data/k_means_visual.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-3730988d37c9> in <module>
# ----> 1 k_means_visual.to_csv('data/k_means_visual.csv', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/k_means_visual.csv'

# %%
# !pip install folium

# %%
import os
import geopandas as gpd
import folium

# %%
k_means_visual

# %%
map_df_1 = gpd.read_file('../data/neighbourhoods.geojson')
map_df_1.head()

# %%
map_df_new = map_df_1[map_df_1['neighbourhood'].isin(top_10_list)]

# %%
map_df_new.head(10)

# %%
# construct a geodataframe
k_means_map_geo = gpd.GeoDataFrame(k_means_visual, geometry=gpd.points_from_xy(k_means_visual.longitude,
                                                                            k_means_visual.latitude))

# %%
k_means_map_geo.head()

# %%
# get long beach neighborhood
Beverly_Grove = map_df_new[map_df_new.neighbourhood == 'Beverly Grove'].geometry
ax2=Beverly_Grove.plot()

# %%
k_means_map_geo['neighbourhood'] = map_df_new['neighbourhood']

# %%
k_means_map_geo.shape

# %%
BH_listings = k_means_map_geo[k_means_map_geo['neighbourhood_Beverly Grove']==1]
BH_listings

# %%
m = folium.Map(location=[34.0735, -118.3766], zoom_start=14)
folium.GeoJson('../data/neighbourhoods.geojson').add_to(m)
# Build markers and popups
for index, row in BH_listings.iterrows():
    row_values = row[1]
#     center_point = row_values['geometry']
    location = [float(row['latitude']), float(row['longitude'])]
    if row['cluster'] == 0:
        marker_color = 'lightred'
    elif row['cluster'] == 1:
        marker_color = 'cadetblue'
    else:
        marker_color = 'lightgreen'
    popup = ('Pool: ' + str(row['pool']) +
             '  ' + 'PRICE: $' + str(row['daily_price']))
    marker = folium.Marker(location = location, popup = popup, icon=folium.Icon(color=marker_color, icon='home'))
    marker.add_to(m)

display(m)
