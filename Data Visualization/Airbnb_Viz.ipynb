# %%
# !pip install sklearn --upgrade

# %%
# Importing required libraries
import pandas as pd
import numpy as np
from numpy.random import seed
seed(123)

import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime

plt.style.use('seaborn')
import seaborn as sns

import geopandas as gpd
import time
import re
import xgboost as xgb
from xgboost import plot_importance

# suppress all warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Home Laptop\Anaconda3\lib\site-packages\dask\dataframe\utils.py:14: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
from sklearn.metrics import explained_variance_score, mean_squared_error, r2_score
from keras import models, layers, optimizers, regularizers
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# !pip install xgboost

# %%
# conda install geopandas

# %%
df = pd.read_csv('merged_data.csv', low_memory=False)

# checking shape
print("The dataset has {} rows and {} columns.".format(*df.shape))

# ... and duplicates
print("It contains {} duplicates.".format(df.duplicated().sum()))
# Out:
# The dataset has 719335 rows and 58 columns.
# It contains 764 duplicates.

# %%
df.head(1)
# Out:
#    price_id  daily_price  weekly_price  cleaning_fee  security_deposit  \
# 0         3         55.0           NaN           NaN               NaN
#
#    availability_id  availability_30  availability_60  availability_90  \
# 0                3               18               43               73
#
#    amenity_id  ...  bathrooms  accommodates  beds     room_type  \
# 0           3  ...        1.0             2   1.0  Private room
#
#    minimum_nights  maximum_nights  latitude   longitude  neighbourhood  \
# 0               1            1125  34.51013 -118.212407          Acton
#
#    zipcode
# 0    93510
#
# [1 rows x 58 columns]

# %%
df.columns
# Out:
# Index(['price_id', 'daily_price', 'weekly_price', 'cleaning_fee',
#        'security_deposit', 'availability_id', 'availability_30',
#        'availability_60', 'availability_90', 'amenity_id', 'wireless_Internet',
#        'air_conditioning', 'pool', 'self_check_in', 'private_entrance',
#        'breakfast', 'free_parking_on_premises', 'tv', 'gym', 'hot_tub',
#        'indoor_fireplace', 'heating', 'family_kid_friendly', 'washer', 'dryer',
#        'hangers', 'iron', 'shampoo', 'hair_dryer', 'high_chair', 'crib',
#        'carbon_monoxide_detector', 'smoke_detector',
#        'babysitter_recommendations', 'pets_allowed', 'first_aid_kit',
#        'host_id', 'host_since', 'host_is_superhost', 'host_response_time',
#        'property_id', 'number_of_reviews', 'review_scores_rating', 'comments',
#        'neighborhood_id', 'listing_description', 'property_type', 'bedrooms',
#        'bathrooms', 'accommodates', 'beds', 'room_type', 'minimum_nights',
#        'maximum_nights', 'latitude', 'longitude', 'neighbourhood', 'zipcode'],
#       dtype='object')

# %%
df = df.drop(columns=['price_id','availability_id','amenity_id', 'neighborhood_id','host_id'])

# %%
df
# Out:
#         daily_price  weekly_price  cleaning_fee  security_deposit  \
# 0              55.0           NaN           NaN               NaN
# 1              55.0           NaN           NaN               NaN
# 2              55.0           NaN           NaN               NaN
# 3              55.0           NaN           NaN               NaN
# 4              55.0           NaN           NaN               NaN
# ...             ...           ...           ...               ...
# 719330        115.0           NaN           NaN               NaN
# 719331        115.0           NaN           NaN               NaN
# 719332        115.0           NaN           NaN               NaN
# 719333        115.0           NaN           NaN               NaN
# 719334        115.0           NaN           NaN               NaN
#
#         availability_30  availability_60  availability_90  wireless_Internet  \
# 0                    18               43               73                  1
# 1                    18               43               73                  1
# 2                    18               43               73                  1
# 3                    18               43               73                  1
# 4                    18               43               73                  1
# ...                 ...              ...              ...                ...
# 719330                5               19               43                  1
# 719331                5               19               43                  1
# 719332                5               19               43                  1
# 719333                5               19               43                  1
# 719334                5               19               43                  1
#
#         air_conditioning  pool  ...  bathrooms  accommodates  beds  \
# 0                      1     0  ...        1.0             2   1.0
# 1                      1     0  ...        1.0             2   1.0
# 2                      1     0  ...        1.0             2   1.0
# 3                      1     0  ...        1.0             2   1.0
# 4                      1     0  ...        1.0             2   1.0
# ...                  ...   ...  ...        ...           ...   ...
# 719330                 1     0  ...        1.0             4   3.0
# 719331                 1     0  ...        1.0             4   3.0
# 719332                 1     0  ...        1.0             4   3.0
# 719333                 1     0  ...        1.0             4   3.0
# 719334                 1     0  ...        1.0             4   3.0
#
#               room_type  minimum_nights  maximum_nights   latitude  \
# 0          Private room               1            1125  34.510130
# 1          Private room               1            1125  34.510130
# 2          Private room               1            1125  34.510130
# 3          Private room               1            1125  34.510130
# 4          Private room               1            1125  34.510130
# ...                 ...             ...             ...        ...
# 719330  Entire home/apt               1              30  34.168772
# 719331  Entire home/apt               1              30  34.168772
# 719332  Entire home/apt               1              30  34.168772
# 719333  Entire home/apt               1              30  34.168772
# 719334  Entire home/apt               1              30  34.168772
#
#          longitude   neighbourhood  zipcode
# 0      -118.212407           Acton    93510
# 1      -118.212407           Acton    93510
# 2      -118.212407           Acton    93510
# 3      -118.212407           Acton    93510
# 4      -118.212407           Acton    93510
# ...            ...             ...      ...
# 719330 -118.614956  Woodland Hills    91367
# 719331 -118.614956  Woodland Hills    91367
# 719332 -118.614956  Woodland Hills    91367
# 719333 -118.614956  Woodland Hills    91367
# 719334 -118.614956  Woodland Hills    91367
#
# [719335 rows x 53 columns]

# %%
df.room_type.value_counts(normalize=True)
# Out:
# Entire home/apt    0.665620
# Private room       0.327543
# Shared room        0.006837
# Name: room_type, dtype: float64

# %%
df.property_type.value_counts(normalize=True)
# Out:
# House                 0.500607
# Apartment             0.315251
# Guesthouse            0.053184
# Bungalow              0.028325
# Condominium           0.017508
# Loft                  0.016649
# Other                 0.016588
# Townhouse             0.013187
# Bed & Breakfast       0.011256
# Cabin                 0.008511
# Camper/RV             0.005355
# Villa                 0.003710
# Guest suite           0.002595
# Dorm                  0.001963
# Chalet                0.000988
# Treehouse             0.000777
# In-law                0.000573
# Yurt                  0.000503
# Hostel                0.000478
# Serviced apartment    0.000417
# Tipi                  0.000377
# Boutique hotel        0.000375
# Hut                   0.000318
# Vacation home         0.000267
# Castle                0.000118
# Island                0.000110
# Earth House           0.000010
# Name: property_type, dtype: float64

# %%
# Replacing categories that are types of houses or apartments
df.property_type.replace({
    'Townhouse': 'House',
    'Serviced apartment': 'Apartment',
    'Loft': 'Apartment',
    'Bungalow': 'House',
    'Cottage': 'House',
    'Villa': 'House',
    'Tiny house': 'House',
    'Earth house': 'House',
    'Chalet': 'House'  
    }, inplace=True)

# Replacing other categories with 'other'
df.loc[~df.property_type.isin(['House', 'Apartment']), 'property_type'] = 'Other'

# %%
df[['daily_price', 'cleaning_fee', 'security_deposit']].head(3)
# Out:
#    daily_price  cleaning_fee  security_deposit
# 0         55.0           NaN               NaN
# 1         55.0           NaN               NaN
# 2         55.0           NaN               NaN

# %%
# checking Nan's in "price" column
df.daily_price.isna().sum()
# Out:
# 0

# %%
# Nan's in "cleaning_fee" column
df.cleaning_fee.isna().sum()
# Out:
# 105962

# %%
#assumption:replace these null values with $0.00
df.cleaning_fee.fillna('$0.00', inplace=True)
df.cleaning_fee.isna().sum()
# Out:
# 0

# %%
df.security_deposit.isna().sum()
# Out:
# 280935

# %%
df.security_deposit.fillna('$0.00', inplace=True)
df.security_deposit.isna().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# daily_price                   float64
# weekly_price                  float64
# cleaning_fee                   object
# security_deposit               object
# availability_30                 int64
# availability_60                 int64
# availability_90                 int64
# wireless_Internet               int64
# air_conditioning                int64
# pool                            int64
# self_check_in                   int64
# private_entrance                int64
# breakfast                       int64
# free_parking_on_premises        int64
# tv                              int64
# gym                             int64
# hot_tub                         int64
# indoor_fireplace                int64
# heating                         int64
# family_kid_friendly             int64
# washer                          int64
# dryer                           int64
# hangers                         int64
# iron                            int64
# shampoo                         int64
# hair_dryer                      int64
# high_chair                      int64
# crib                            int64
# carbon_monoxide_detector        int64
# smoke_detector                  int64
# babysitter_recommendations      int64
# pets_allowed                    int64
# first_aid_kit                   int64
# host_since                     object
# host_is_superhost             float64
# host_response_time             object
# property_id                     int64
# number_of_reviews               int64
# review_scores_rating          float64
# comments                       object
# listing_description            object
# property_type                  object
# bedrooms                      float64
# bathrooms                     float64
# accommodates                    int64
# beds                          float64
# room_type                      object
# minimum_nights                  int64
# maximum_nights                  int64
# latitude                      float64
# longitude                     float64
# neighbourhood                  object
# zipcode                        object
# dtype: object

# %%
df['daily_price'].describe()
# Out:
# count    719335.000000
# mean        135.123250
# std         152.505431
# min          19.000000
# 25%          75.000000
# 50%         103.000000
# 75%         150.000000
# max        7500.000000
# Name: daily_price, dtype: float64

# %%
#price distribution
red_square = dict(markerfacecolor='r', markeredgecolor='r', marker='.')
df['daily_price'].plot(kind='box', xlim=(0, 1000), vert=False, flierprops=red_square, figsize=(16,2));

# %%
df.drop(df[ (df.daily_price > 500) | (df.daily_price == 0) ].index, axis=0, inplace=True)

# %%
df['daily_price'].describe()
# Out:
# count    708627.000000
# mean        123.749952
# std          75.942083
# min          19.000000
# 25%          75.000000
# 50%         100.000000
# 75%         149.000000
# max         500.000000
# Name: daily_price, dtype: float64

# %%
print("The dataset has {} rows and {} columns - after being price-wise preprocessed.".format(*df.shape))
# Out:
# The dataset has 708627 rows and 53 columns - after being price-wise preprocessed.

# %%
pd.set_option('display.max_columns', None)

# %%
test = df.dropna()

# %%
test.head()
# Out:
#      daily_price  weekly_price cleaning_fee security_deposit  availability_30  \
# 240         79.0         400.0           20            $0.00               27
# 241         79.0         400.0           20            $0.00               27
# 242         79.0         400.0           20            $0.00               27
# 243         79.0         400.0           20            $0.00               27
# 244         79.0         400.0           20            $0.00               27
#
#      availability_60  availability_90  wireless_Internet  air_conditioning  \
# 240               45               70                  1                 0
# 241               45               70                  1                 0
# 242               45               70                  1                 0
# 243               45               70                  1                 0
# 244               45               70                  1                 0
#
#      pool  self_check_in  private_entrance  breakfast  \
# 240     0              0                 0          0
# 241     0              0                 0          0
# 242     0              0                 0          0
# 243     0              0                 0          0
# 244     0              0                 0          0
#
#      free_parking_on_premises  tv  gym  hot_tub  indoor_fireplace  heating  \
# 240                         1   1    0        0                 0        1
# 241                         1   1    0        0                 0        1
# 242                         1   1    0        0                 0        1
# 243                         1   1    0        0                 0        1
# 244                         1   1    0        0                 0        1
#
#      family_kid_friendly  washer  dryer  hangers  iron  shampoo  hair_dryer  \
# 240                    0       1      1        1     0        0           0
# 241                    0       1      1        1     0        0           0
# 242                    0       1      1        1     0        0           0
# 243                    0       1      1        1     0        0           0
# 244                    0       1      1        1     0        0           0
#
#      high_chair  crib  carbon_monoxide_detector  smoke_detector  \
# 240           0     0                         1               1
# 241           0     0                         1               1
# 242           0     0                         1               1
# 243           0     0                         1               1
# 244           0     0                         1               1
#
#      babysitter_recommendations  pets_allowed  first_aid_kit  host_since  \
# 240                           0             1              0  2012-05-08
# 241                           0             1              0  2012-05-08
# 242                           0             1              0  2012-05-08
# 243                           0             1              0  2012-05-08
# 244                           0             1              0  2012-05-08
#
#      host_is_superhost  host_response_time  property_id  number_of_reviews  \
# 240                0.0  within a few hours      6153123                  9
# 241                0.0  within a few hours      6153123                  9
# 242                0.0  within a few hours      6153123                  9
# 243                0.0  within a few hours      6153123                  9
# 244                0.0  within a few hours      6153123                  9
#
#      review_scores_rating                                           comments  \
# 240                  70.0  Elisabeth was very welcoming and for the first...
# 241                  70.0  We rented this 1st floor apartment for 3 days....
# 242                  70.0  Nous navons pas eu la possibilité de discuter ...
# 243                  70.0  Its good place with that price, helpful people...
# 244                  70.0  Debbie who lived upstairs was a gracious and t...
#
#                                    listing_description property_type  \
# 240  Private spacious room with private attached ba...         Other
# 241  Private spacious room with private attached ba...         Other
# 242  Private spacious room with private attached ba...         Other
# 243  Private spacious room with private attached ba...         Other
# 244  Private spacious room with private attached ba...         Other
#
#      bedrooms  bathrooms  accommodates  beds     room_type  minimum_nights  \
# 240       1.0        1.0             4   1.0  Private room               1
# 241       1.0        1.0             4   1.0  Private room               1
# 242       1.0        1.0             4   1.0  Private room               1
# 243       1.0        1.0             4   1.0  Private room               1
# 244       1.0        1.0             4   1.0  Private room               1
#
#      maximum_nights   latitude   longitude    neighbourhood zipcode
# 240            1125  34.030587 -118.299548  Adams-Normandie   90007
# 241            1125  34.030587 -118.299548  Adams-Normandie   90007
# 242            1125  34.030587 -118.299548  Adams-Normandie   90007
# 243            1125  34.030587 -118.299548  Adams-Normandie   90007
# 244            1125  34.030587 -118.299548  Adams-Normandie   90007

# %%
# !pip install geopy

# %%
from geopy.distance import great_circle

# %%
def distance_to_mid(latitude, longitude):
    los_angeles_center = (34.0522, -118.2437)
    accommodation = (latitude, longitude)
    return great_circle(los_angeles_center, accommodation).km

# %%
test['distance'] = test.apply(lambda x: distance_to_mid(x.latitude, x.longitude), axis=1)

# %%
test["cleaning_fee_2"] = test["cleaning_fee"].astype(str).str.replace('$', '').str.replace(',', '').astype(float)
test["security_deposit_2"] = test["security_deposit"].astype(str).str.replace('$', '').str.replace(',', '').astype(float)
test["distance"] = test["distance"].astype(str).str.replace('km', '').str.replace(',', '').astype(float)

# %%
test_500 = test.loc[test['daily_price']<=500]
test_sorted = test_500.sort_values(['daily_price'], ascending=False)

# %%
test_distance = test_500.groupby('distance').mean()['daily_price'].reset_index()

# %%
test_distance
# Out:
#        distance  daily_price
# 0      0.614908         60.0
# 1      0.707075         83.0
# 2      0.746310         36.0
# 3      0.763141         58.0
# 4      0.817459        110.0
# ...         ...          ...
# 2277  61.484315        149.0
# 2278  62.031512         85.0
# 2279  62.681837         35.0
# 2280  64.334319         40.0
# 2281  64.804645        395.0
#
# [2282 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
test_distance
# Out:
#        distance  daily_price
# 0      0.614908         60.0
# 1      0.707075         83.0
# 2      0.746310         36.0
# 3      0.763141         58.0
# 4      0.817459        110.0
# 5      0.821658         35.0
# 6      0.839761         36.0
# 7      0.859587        143.0
# 8      0.905015        145.0
# 9      0.912015        100.0
# 10     0.918738        155.0
# 11     0.931594        150.0
# 12     0.956513        125.0
# 13     0.981385        125.0
# 14     1.013774         95.0
# 15     1.055392        125.0
# 16     1.078299         85.0
# 17     1.081287         99.0
# 18     1.102015         70.0
# 19     1.107282        150.0
# 20     1.128213        129.0
# 21     1.162391        130.0
# 22     1.169566        155.0
# 23     1.193908        149.0
# 24     1.210683        229.0
# 25     1.380451        150.0
# 26     1.439700         77.0
# 27     1.607002         77.0
# 28     1.655334         55.0
# 29     1.703459        129.0
# 30     1.721966        137.0
# 31     1.789168         63.0
# 32     1.790774         79.0
# 33     1.812179         45.0
# 34     1.812416         79.0
# 35     1.829134        199.0
# 36     1.865858        249.0
# 37     1.886347        100.0
# 38     2.050459         92.0
# 39     2.144625        269.0
# 40     2.237317         75.0
# 41     2.281230        175.0
# 42     2.362781        115.0
# 43     2.399410        289.0
# 44     2.400279        108.0
# 45     2.450503         60.0
# 46     2.493953         68.0
# 47     2.603069         60.0
# 48     2.620331         71.0
# 49     2.690102        138.0
# 50     2.719132        320.0
# 51     2.720125         75.0
# 52     2.795653         50.0
# 53     2.937859        135.0
# 54     2.988227        160.0
# 55     2.996598         99.0
# 56     3.067748         99.0
# 57     3.076707        250.0
# 58     3.093274         65.0
# 59     3.095267         72.0
# 60     3.138953         45.0
# 61     3.233357         45.0
# 62     3.264570         65.0
# 63     3.375680         51.0
# 64     3.384329         41.0
# 65     3.398426         95.0
# 66     3.402264         65.0
# 67     3.414906         45.0
# 68     3.438704         50.0
# 69     3.448511         54.0
# 70     3.470364         55.0
# 71     3.473945        230.0
# 72     3.507876        115.0
# 73     3.537426        189.0
# 74     3.596920        129.0
# 75     3.605189         84.0
# 76     3.611839         95.0
# 77     3.613162         85.0
# 78     3.663241         90.0
# 79     3.674853         38.0
# 80     3.726266         91.0
# 81     3.740336        125.0
# 82     3.742292         67.0
# 83     3.786971        110.0
# 84     3.787581        141.0
# 85     3.804345        155.0
# 86     3.855908         67.0
# 87     3.860706        310.0
# 88     3.869007        122.0
# 89     3.877237        260.0
# 90     3.885415         80.0
# 91     3.954562         90.0
# 92     3.983158        220.0
# 93     3.990151        110.0
# 94     4.020826        189.0
# 2193  37.439976         42.0
# 2194  37.504831         89.0
# 2195  37.524122         37.0
# 2196  37.669793         88.0
# 2197  37.702823         65.0
# 2198  37.715717         99.0
# 2199  37.745495        140.0
# 2200  37.777972         75.0
# 2201  37.909138        175.0
# 2202  38.020268         40.0
# 2203  38.165093         75.0
# 2204  38.288264         62.0
# 2205  38.343606         52.0
# 2206  38.371690        155.0
# 2207  38.402715        155.0
# 2208  38.411384         79.0
# 2209  38.459342         70.0
# 2210  38.494856         47.0
# 2211  38.748289        154.0
# 2212  39.042359        299.0
# 2213  39.135586         67.0
# 2214  39.315390         69.0
# 2215  39.332122        182.0
# 2216  39.453707         80.0
# 2217  39.592618        450.0
# 2218  39.608316        400.0
# 2219  39.610745         39.0
# 2220  39.674051        500.0
# 2221  39.835430         81.0
# 2222  40.079612         80.0
# 2223  40.162481        140.0
# 2224  40.163312         95.0
# 2225  41.464886         64.0
# 2226  43.336422         79.0
# 2227  43.397987         79.0
# 2228  44.165120        350.0
# 2229  44.199883        189.0
# 2230  44.535818         65.0
# 2231  44.837093        300.0
# 2232  44.843667         55.0
# 2233  45.429273         49.0
# 2234  45.584151         58.0
# 2235  45.701357        395.0
# 2236  45.913267        207.0
# 2237  46.051592        334.0
# 2238  46.075867        169.0
# 2239  46.260661         85.0
# 2240  47.036092         62.0
# 2241  47.150080         60.0
# 2242  47.207990        300.0
# 2243  47.248032        180.0
# 2244  47.348428        220.0
# 2245  48.034764        230.0
# 2246  48.116950         59.0
# 2247  48.195474         85.0
# 2248  48.541525         55.0
# 2249  48.752013         28.0
# 2250  49.274198        145.0
# 2251  49.301717         75.0
# 2252  49.578180         75.0
# 2253  50.131885        120.0
# 2254  50.489860        398.0
# 2255  50.621531         38.0
# 2256  50.722329        134.0
# 2257  50.725595         65.0
# 2258  50.816631        199.0
# 2259  51.037078        200.0
# 2260  51.293436         80.0
# 2261  51.460705        340.0
# 2262  52.179774        215.0
# 2263  52.247807         56.0
# 2264  52.404786         54.0
# 2265  52.446334         99.0
# 2266  52.463678         51.0
# 2267  52.670701         60.0
# 2268  52.764639        395.0
# 2269  52.817927        330.0
# 2270  53.070305        250.0
# 2271  57.815830         55.0
# 2272  58.605030        159.0
# 2273  58.714106         99.0
# 2274  59.091066        195.0
# 2275  59.651438        120.0
# 2276  61.382828        149.0
# 2277  61.484315        149.0
# 2278  62.031512         85.0
# 2279  62.681837         35.0
# 2280  64.334319         40.0
# 2281  64.804645        395.0

# %%
test_sorted.shape
# Out:
# (238450, 56)

# %%
test['listing_description']
# Out:
# 240       Private spacious room with private attached ba...
# 241       Private spacious room with private attached ba...
# 242       Private spacious room with private attached ba...
# 243       Private spacious room with private attached ba...
# 244       Private spacious room with private attached ba...
#                                 ...
# 718835    Private room with bright window light and view...
# 718836    Private room with bright window light and view...
# 718837    Private room with bright window light and view...
# 718838    Private room with bright window light and view...
# 718839    Private room with bright window light and view...
# Name: listing_description, Length: 238450, dtype: object

# %%
# extract numbers 
test['size'] = test['listing_description'].str.extract('(\d{2,3}\s?[smSM])', expand=True)
test['size'] = test['size'].str.replace("\D", "")

# %%
# change datatype of size into float
test['size'] = test['size'].astype(float)

# %%
print('NaNs in size_column absolute:     ', test['size'].isna().sum())
print('NaNs in size_column in percentage:', round(test['size'].isna().sum()/len(test),3), '%')
# Out:
# NaNs in size_column absolute:      140889
# NaNs in size_column in percentage: 0.591 %

# %%
test[['listing_description', 'size']].head(10)
# Out:
#                                    listing_description  size
# 240  Private spacious room with private attached ba...   NaN
# 241  Private spacious room with private attached ba...   NaN
# 242  Private spacious room with private attached ba...   NaN
# 243  Private spacious room with private attached ba...   NaN
# 244  Private spacious room with private attached ba...   NaN
# 245  Private spacious room with private attached ba...   NaN
# 246  Private spacious room with private attached ba...   NaN
# 247  Private spacious room with private attached ba...   NaN
# 248  Private spacious room with private attached ba...   NaN
# 249  Private spacious room with private attached ba...   NaN

# %%
test.listing_description.isna().sum()
# Out:
# 0

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238450 entries, 240 to 718839
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   daily_price                 238450 non-null  float64
#  1   weekly_price                238450 non-null  float64
#  2   cleaning_fee                238450 non-null  object
#  3   security_deposit            238450 non-null  object
#  4   availability_30             238450 non-null  int64
#  5   availability_60             238450 non-null  int64
#  6   availability_90             238450 non-null  int64
#  7   wireless_Internet           238450 non-null  int64
#  8   air_conditioning            238450 non-null  int64
#  9   pool                        238450 non-null  int64
#  10  self_check_in               238450 non-null  int64
#  11  private_entrance            238450 non-null  int64
#  12  breakfast                   238450 non-null  int64
#  13  free_parking_on_premises    238450 non-null  int64
#  14  tv                          238450 non-null  int64
#  15  gym                         238450 non-null  int64
#  16  hot_tub                     238450 non-null  int64
#  17  indoor_fireplace            238450 non-null  int64
#  18  heating                     238450 non-null  int64
#  19  family_kid_friendly         238450 non-null  int64
#  20  washer                      238450 non-null  int64
#  21  dryer                       238450 non-null  int64
#  22  hangers                     238450 non-null  int64
#  23  iron                        238450 non-null  int64
#  24  shampoo                     238450 non-null  int64
#  25  hair_dryer                  238450 non-null  int64
#  26  high_chair                  238450 non-null  int64
#  27  crib                        238450 non-null  int64
#  28  carbon_monoxide_detector    238450 non-null  int64
#  29  smoke_detector              238450 non-null  int64
#  30  babysitter_recommendations  238450 non-null  int64
#  31  pets_allowed                238450 non-null  int64
#  32  first_aid_kit               238450 non-null  int64
#  33  host_since                  238450 non-null  object
#  34  host_is_superhost           238450 non-null  float64
#  35  host_response_time          238450 non-null  object
#  36  property_id                 238450 non-null  int64
#  37  number_of_reviews           238450 non-null  int64
#  38  review_scores_rating        238450 non-null  float64
#  39  comments                    238450 non-null  object
#  40  listing_description         238450 non-null  object
#  41  property_type               238450 non-null  object
#  42  bedrooms                    238450 non-null  float64
#  43  bathrooms                   238450 non-null  float64
#  44  accommodates                238450 non-null  int64
#  45  beds                        238450 non-null  float64
#  46  room_type                   238450 non-null  object
#  47  minimum_nights              238450 non-null  int64
#  48  maximum_nights              238450 non-null  int64
#  49  latitude                    238450 non-null  float64
#  50  longitude                   238450 non-null  float64
#  51  neighbourhood               238450 non-null  object
#  52  zipcode                     238450 non-null  object
#  53  distance                    238450 non-null  float64
#  54  cleaning_fee_2              238450 non-null  float64
#  55  security_deposit_2          238450 non-null  float64
#  56  size                        97561 non-null   float64
# dtypes: float64(13), int64(34), object(10)
# memory usage: 105.5+ MB

# %%
# filter out sub_df to work with
selected_features = test[['accommodates', 'bathrooms', 'bedrooms',  'daily_price', 'cleaning_fee_2', 
                 'security_deposit_2', 'distance','size','availability_90','number_of_reviews']]

# %%
clean_data = selected_features.dropna()

# %%
# Read the training data into a dataframe
X = clean_data[['accommodates', 'bathrooms', 'bedrooms', 'daily_price', 'cleaning_fee_2', 
                 'security_deposit_2','distance','size','availability_90','number_of_reviews']]
y = clean_data['daily_price']

# %%
X.dtypes
# Out:
# accommodates            int64
# bathrooms             float64
# bedrooms              float64
# daily_price           float64
# cleaning_fee_2        float64
# security_deposit_2    float64
# distance              float64
# size                  float64
# availability_90         int64
# number_of_reviews       int64
# dtype: object

# %%
# Converting to datetime
test.host_since = pd.to_datetime(df.host_since)

# %%
# Calculating the number of days
test['host_days_active'] = (datetime(2019, 4, 9) - test.host_since).astype('timedelta64[D]')

# Printing mean and median
print("Mean days as host:", round(test['host_days_active'].mean(),0))
print("Median days as host:", test['host_days_active'].median())

# Replacing null values with the median
test.host_days_active.fillna(test.host_days_active.median(), inplace=True)
# Out:
# Mean days as host: 2100.0
# Median days as host: 2066.0

# %%
test_active_days = test.groupby('host_days_active').mean()['daily_price'].reset_index()

# %%
test_active_days['host_days_active'] = np.log(test_active_days['host_days_active'])

# %%
test_active_days
# Out:
#       host_days_active  daily_price
# 0             6.909753    82.000000
# 1             6.913737    46.526316
# 2             6.922644    60.000000
# 3             6.931472    69.000000
# 4             6.936343    46.000000
# ...                ...          ...
# 1124          8.218248    68.000000
# 1125          8.225503    59.340909
# 1126          8.253488    86.974359
# 1127          8.257386   177.727273
# 1128          8.278428   122.000000
#
# [1129 rows x 2 columns]

# %%
plt.scatter(test_active_days['host_days_active'], test_active_days['daily_price'], marker='o');

# %%
test.dtypes
# Out:
# daily_price                          float64
# weekly_price                         float64
# cleaning_fee                          object
# security_deposit                      object
# availability_30                        int64
# availability_60                        int64
# availability_90                        int64
# wireless_Internet                      int64
# air_conditioning                       int64
# pool                                   int64
# self_check_in                          int64
# private_entrance                       int64
# breakfast                              int64
# free_parking_on_premises               int64
# tv                                     int64
# gym                                    int64
# hot_tub                                int64
# indoor_fireplace                       int64
# heating                                int64
# family_kid_friendly                    int64
# washer                                 int64
# dryer                                  int64
# hangers                                int64
# iron                                   int64
# shampoo                                int64
# hair_dryer                             int64
# high_chair                             int64
# crib                                   int64
# carbon_monoxide_detector               int64
# smoke_detector                         int64
# babysitter_recommendations             int64
# pets_allowed                           int64
# first_aid_kit                          int64
# host_since                    datetime64[ns]
# host_is_superhost                    float64
# host_response_time                    object
# property_id                            int64
# number_of_reviews                      int64
# review_scores_rating                 float64
# comments                              object
# listing_description                   object
# property_type                         object
# bedrooms                             float64
# bathrooms                            float64
# accommodates                           int64
# beds                                 float64
# room_type                             object
# minimum_nights                         int64
# maximum_nights                         int64
# latitude                             float64
# longitude                            float64
# neighbourhood                         object
# zipcode                               object
# distance                             float64
# cleaning_fee_2                       float64
# security_deposit_2                   float64
# size                                 float64
# host_days_active                     float64
# dtype: object

# %%
df.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4, figsize=(10,7), 
        c="daily_price", cmap="gist_heat_r", colorbar=True, sharex=False);

# %%
# host_since time series graph
plt.figure(figsize=(15,5))
df.set_index('host_since').size().plot(label='Hosts joining Airbnb', color='orange')
# df.set_index('daily_price').resample('MS').size().plot(label='Price charged by host', color='green')
# plt.title('LA hosts joining Airbnb')
# plt.legend()
# plt.xlim('2008-08-01', '2019-03-31') # Limiting to whole months
# plt.xlabel('year')
# plt.ylabel('')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-e1b53e5d15f5> in <module>
#       1 plt.figure(figsize=(15,5))
# ----> 2 df.set_index('host_since').size().plot(label='Hosts joining Airbnb', color='orange')
#       3 # df.set_index('daily_price').resample('MS').size().plot(label='Price charged by host', color='green')
#       4 # plt.title('LA hosts joining Airbnb')
#       5 # plt.legend()
#
# TypeError: 'numpy.int32' object is not callable

# %%
plt.figure(figsize=(10,5))
df.groupby('accommodates').daily_price.median().plot(kind='bar')
plt.title('Median price of Airbnbs accommodating different number of guests', fontsize=14)
plt.xlabel('Number of guests accommodated', fontsize=13)
plt.ylabel('Median price ($)', fontsize=13)
plt.xticks(rotation=0)
plt.xlim(left=0.5)
plt.show()

# %%
# Checking the distributions of the review ratings columns
variables_to_plot = list(df.columns[df.columns.str.startswith("review_scores") == True])
fig = plt.figure(figsize=(12,8))
for i, var_name in enumerate(variables_to_plot):
    ax = fig.add_subplot(3,3,i+1)
    df[var_name].hist(bins=10,ax=ax)
    ax.set_title(var_name)
fig.tight_layout()
plt.show()

# %%
# Importing the London borough boundary GeoJSON file as a dataframe in geopandas
map_df = gpd.read_file('data/neighbourhoods.geojson')
map_df.head()
# Out:
#    neighbourhood   neighbourhood_group  \
# 0  Angeles Crest  Unincorporated Areas
# 1          Acton  Unincorporated Areas
# 2     Agua Dulce  Unincorporated Areas
# 3         Athens  Unincorporated Areas
# 4   Alondra Park  Unincorporated Areas
#
#                                             geometry
# 0  MULTIPOLYGON (((-118.09667 34.47348, -118.0796...
# 1  MULTIPOLYGON (((-118.20703 34.53902, -118.1894...
# 2  MULTIPOLYGON (((-118.37822 34.48811, -118.3783...
# 3  MULTIPOLYGON (((-118.29152 33.93096, -118.2916...
# 4  MULTIPOLYGON (((-118.32651 33.89757, -118.3264...

# %%
# Dropping the empty column
map_df.drop('neighbourhood_group', axis=1, inplace=True)

# %%
# Creating a dataframe of listing counts and median price by borough
borough_df = pd.DataFrame(test.groupby('neighbourhood').size())
borough_df = borough_df.rename(columns={0: 'number_of_listings'})
borough_df['median_price'] = test.groupby('neighbourhood').daily_price.mean().values
borough_map_df = map_df.set_index('neighbourhood').join(borough_df)

# %%
borough_map_df = borough_map_df.iloc[:50, :]

# %%
borough_map_df.number_of_listings.dropna()
# Out:
# neighbourhood
# Angeles Crest             154.0
# Agua Dulce                163.0
# Alondra Park              118.0
# Altadena                 2523.0
# Charter Oak               283.0
# Del Aire                  127.0
# East Los Angeles          399.0
# East Pasadena              45.0
# East San Gabriel           96.0
# Green Valley              169.0
# Hacienda Heights          206.0
# La Crescenta-Montrose      27.0
# Ladera Heights            415.0
# Marina del Rey              3.0
# Lennox                     51.0
# Castaic Canyons            21.0
# Rowland Heights          1188.0
# San Pasqual               105.0
# North Whittier              5.0
# South San Gabriel         150.0
# Sun Village                 2.0
# Val Verde                  99.0
# Stevenson Ranch           192.0
# Name: number_of_listings, dtype: float64

# %%
# Plotting the number of listings in each borough
fig1, ax1 = plt.subplots(1, figsize=(15, 6))
borough_map_df.plot('number_of_listings', cmap='Blues', ax=ax1)
ax1.axis('off')
ax1.set_title('Number of Airbnb listings in each LA neighbourhood', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=9000))
sm._A = [] # Creates an empty array for the data range
cbar = fig1.colorbar(sm)
plt.show()

# %%
# Plotting the median price of listings in each borough
fig2, ax2 = plt.subplots(1, figsize=(15, 6))
borough_map_df.plot('median_price', cmap='Blues', ax=ax2)
ax2.axis('off')
ax2.set_title('Median price of Airbnb listings in each LA neighbourhood', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=min(borough_map_df.median_price), vmax=max(borough_map_df.median_price)))
sm._A = [] # Creates an empty array for the data range
cbar = fig2.colorbar(sm)
plt.show()

# %%
test_distance.shape
# Out:
# (2282, 2)

# %%
test_distance = test_distance.iloc[:50,:]

# %%
# box-plot
red_square = dict(markerfacecolor='salmon', markeredgecolor='salmon', marker='.')

test.boxplot(column='distance', by='daily_price', 
           flierprops=red_square, vert=False, figsize=(10,8))

plt.xlabel('\n Distance', fontsize=12)
plt.ylabel(' Mean Price\n', fontsize=12)
plt.title('\n Does Distance to downtown affect Airbnb Price? \n', fontsize=14, fontweight='bold')

# get rid of automatic boxplot title
plt.suptitle('');

# %%
test
# Out:
#     distance  daily_price
# 0   0.614908         60.0
# 1   0.707075         83.0
# 2   0.746310         36.0
# 3   0.763141         58.0
# 4   0.817459        110.0
# 5   0.821658         35.0
# 6   0.839761         36.0
# 7   0.859587        143.0
# 8   0.905015        145.0
# 9   0.912015        100.0
# 10  0.918738        155.0
# 11  0.931594        150.0
# 12  0.956513        125.0
# 13  0.981385        125.0
# 14  1.013774         95.0
# 15  1.055392        125.0
# 16  1.078299         85.0
# 17  1.081287         99.0
# 18  1.102015         70.0
# 19  1.107282        150.0
# 20  1.128213        129.0
# 21  1.162391        130.0
# 22  1.169566        155.0
# 23  1.193908        149.0
# 24  1.210683        229.0
# 25  1.380451        150.0
# 26  1.439700         77.0
# 27  1.607002         77.0
# 28  1.655334         55.0
# 29  1.703459        129.0
# 30  1.721966        137.0
# 31  1.789168         63.0
# 32  1.790774         79.0
# 33  1.812179         45.0
# 34  1.812416         79.0
# 35  1.829134        199.0
# 36  1.865858        249.0
# 37  1.886347        100.0
# 38  2.050459         92.0
# 39  2.144625        269.0
# 40  2.237317         75.0
# 41  2.281230        175.0
# 42  2.362781        115.0
# 43  2.399410        289.0
# 44  2.400279        108.0
# 45  2.450503         60.0
# 46  2.493953         68.0
# 47  2.603069         60.0
# 48  2.620331         71.0
# 49  2.690102        138.0

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,5))
ax.set_title('host experience', fontsize=16)
test_active_days['host_days_active'].value_counts().sort_index(ascending=True).plot(kind='bar', color=['silver', 'darkgreen', 'yellowgreen', '#d1f28a' ], ax=ax)
ax.set_xlabel('Number of Days Active')
ax.set_ylabel('Days active', fontsize=13)
plt.show()

# %%
def multi_collinearity_heatmap(df, figsize=(11,9)):
    
    """
    Creates a heatmap of correlations between features in the df. A figure size can optionally be set.
    """
    
    # Set the style of the visualization
    sns.set(style="white")

    # Create a covariance matrix
    corr = test.corr()

    # Generate a mask the size of our covariance matrix
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=figsize)

    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5}, vmax=corr[corr != 1.0].max().max());

# %%
multi_collinearity_heatmap(test, figsize=(20,20))
